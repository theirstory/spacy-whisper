# %%
from spacy_whisper import SpacyWhisper
import json

# %%
with open("whisper_output.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
sw = SpacyWhisper(lang="en", model="en_core_web_sm", segments_key="segments", word_level=True)
doc = sw.create_doc(data)

# %%
doc
# Out:
# One of the most useful things you can learn as an intermediate Python student is comprehension. List comprehension looks something like this. Imagine we had a list of names, Tom, Cat, and Bob. And I imagine we wanted to grab just the first letter of each of these names. We can do so with list comprehension. Believe it or not, this code is identical to the result that you would get from this code here. Let's break down list comprehension step by step. First, we have our list of names, Tom, Bob, and Cat. Now we're going to use list comprehension. In this case, we're creating an object called L, and it's going to grab the first letter of each of these names. First, we create our object L. This is where we're going to start creating a list that's going to be populated by our comprehension. The comprehension segment comes right here. First, we open up a list just as we normally would. Next, we're going to grab the first index for each thing that we're going to iterate over, in this case N. And then the second component of list comprehension is a standard for loop. And if you print this off, we get the exact result that we would expect. The first letter of each name.

# %%
print(doc._.timestamp_doc)
# Out:
# [00:00:00.000] One of the most useful things you can learn as an intermediate Python student is comprehension.
# [00:00:04.720] List comprehension looks something like this.
# [00:00:07.000] Imagine we had a list of names, Tom, Cat, and Bob.
# [00:00:09.720] And I imagine we wanted to grab just the first letter of each of these names.
# [00:00:13.180] We can do so with list comprehension.
# [00:00:15.460] Believe it or not, this code is identical to the result that you would get from this code here.
# [00:00:20.500] Let's break down list comprehension step by step.
# [00:00:23.100] First, we have our list of names, Tom, Bob, and Cat.
# [00:00:25.920] Now we're going to use list comprehension.
# [00:00:27.540] In this case, we're creating an object called L, and it's going to grab the first letter of each of these names.
# [00:00:33.820] First, we create our object L.
# [00:00:35.760] This is where we're going to start creating a list that's going to be populated by our comprehension.
# [00:00:40.560] The comprehension segment comes right here.
# [00:00:43.040] First, we open up a list just as we normally would.
# [00:00:46.240] Next, we're going to grab the first index for each thing that we're going to iterate over, in this case N.
# [00:00:51.720] And then the second component of list comprehension is a standard for loop.
# [00:00:55.020] And if you print this off, we get the exact result that we would expect.
# [00:00:58.240] The first letter of each name.

# %%
for token in doc:
    print(token, token._.start_time, token._.end_time, token._.split)
# Out:
# One 0.0 0.18 False
# of 0.18 0.18 False
# the 0.18 0.26 False
# most 0.26 0.46 False
# useful 0.46 0.74 False
# things 0.74 1.04 False
# you 1.04 1.14 False
# can 1.14 1.32 False
# learn 1.32 1.56 False
# as 1.56 1.78 False
# an 1.78 1.86 False
# intermediate 1.86 2.26 False
# Python 2.26 2.7 False
# student 2.7 3.14 False
# is 3.14 3.46 False
# comprehension 3.46 4.04 True
# . 3.46 4.04 True
# List 4.72 4.88 False
# comprehension 4.88 5.36 False
# looks 5.36 5.74 False
# something 5.74 6.06 False
# like 6.06 6.3 False
# this 6.3 6.68 True
# . 6.3 6.68 True
# Imagine 7.0 7.28 False
# we 7.28 7.46 False
# had 7.46 7.6 False
# a 7.6 7.68 False
# list 7.68 7.86 False
# of 7.86 7.98 False
# names 7.98 8.34 True
# , 7.98 8.34 True
# Tom 8.4 8.66 True
# , 8.4 8.66 True
# Cat 8.66 8.94 True
# , 8.66 8.94 True
# and 9.1 9.24 False
# Bob 9.24 9.54 True
# . 9.24 9.54 True
# And 9.72 9.72 False
# I 9.72 9.74 False
# imagine 9.74 10.06 False
# we 10.06 10.2 False
# wanted 10.2 10.36 False
# to 10.36 10.5 False
# grab 10.5 10.72 False
# just 10.72 11.02 False
# the 11.02 11.16 False
# first 11.16 11.48 False
# letter 11.48 11.8 False
# of 11.8 12.06 False
# each 12.06 12.2 False
# of 12.2 12.28 False
# these 12.28 12.42 False
# names 12.42 12.86 True
# . 12.42 12.86 True
# We 13.18 13.28 False
# can 13.28 13.5 False
# do 13.5 13.66 False
# so 13.66 13.9 False
# with 13.9 14.04 False
# list 14.04 14.26 False
# comprehension 14.26 14.84 True
# . 14.26 14.84 True
# Believe 15.46 15.64 False
# it 15.64 15.82 False
# or 15.82 15.82 False
# not 15.82 15.98 True
# , 15.82 15.98 True
# this 16.14 16.3 False
# code 16.3 16.58 False
# is 16.58 16.98 False
# identical 16.98 17.56 False
# to 17.56 17.94 False
# the 17.94 18.02 False
# result 18.02 18.34 False
# that 18.34 18.5 False
# you 18.5 18.56 False
# would 18.56 18.68 False
# get 18.68 18.84 False
# from 18.84 19.08 False
# this 19.08 19.58 False
# code 19.58 19.86 False
# here 19.86 20.22 True
# . 19.86 20.22 True
# Let 20.5 20.7 True
# 's 20.5 20.7 True
# break 20.7 20.88 False
# down 20.88 21.2 False
# list 21.2 21.48 False
# comprehension 21.48 21.94 False
# step 21.94 22.34 False
# by 22.34 22.52 False
# step 22.52 22.8 True
# . 22.52 22.8 True
# First 23.1 23.4 True
# , 23.1 23.4 True
# we 23.54 23.56 False
# have 23.56 23.72 False
# our 23.72 23.84 False
# list 23.84 24.08 False
# of 24.08 24.22 False
# names 24.22 24.6 True
# , 24.22 24.6 True
# Tom 24.64 24.94 True
# , 24.64 24.94 True
# Bob 24.94 25.2 True
# , 24.94 25.2 True
# and 25.2 25.3 False
# Cat 25.3 25.58 True
# . 25.3 25.58 True
# Now 25.92 26.1 False
# we 26.1 26.2 True
# 're 26.1 26.2 True
# going 26.2 26.3 False
# to 26.3 26.4 False
# use 26.4 26.58 False
# list 26.58 26.88 False
# comprehension 26.88 27.54 True
# . 26.88 27.54 True
# In 27.54 27.9 False
# this 27.9 28.02 False
# case 28.02 28.2 True
# , 28.02 28.2 True
# we 28.26 28.4 True
# 're 28.26 28.4 True
# creating 28.4 28.62 False
# an 28.62 28.82 False
# object 28.82 29.06 False
# called 29.06 29.48 False
# L 29.48 29.86 True
# , 29.48 29.86 True
# and 30.16 30.22 False
# it 30.22 30.34 True
# 's 30.22 30.34 True
# going 30.34 30.48 False
# to 30.48 30.56 False
# grab 30.56 30.86 False
# the 30.86 31.1 False
# first 31.1 31.56 False
# letter 31.56 31.86 False
# of 31.86 32.18 False
# each 32.18 32.52 False
# of 32.52 32.74 False
# these 32.74 32.98 False
# names 32.98 33.48 True
# . 32.98 33.48 True
# First 33.82 34.06 True
# , 33.82 34.06 True
# we 34.16 34.24 False
# create 34.24 34.44 False
# our 34.44 34.56 False
# object 34.56 34.88 False
# L. 34.88 35.46 False
# This 35.76 35.9 False
# is 35.9 36.02 False
# where 36.02 36.12 False
# we 36.12 36.18 True
# 're 36.12 36.18 True
# going 36.18 36.32 False
# to 36.32 36.42 False
# start 36.42 36.8 False
# creating 36.8 37.24 False
# a 37.24 37.56 False
# list 37.56 38.02 False
# that 38.02 38.26 True
# 's 38.02 38.26 True
# going 38.26 38.42 False
# to 38.42 38.42 False
# be 38.42 38.52 False
# populated 38.52 39.02 False
# by 39.02 39.3 False
# our 39.3 39.46 False
# comprehension 39.46 39.94 True
# . 39.46 39.94 True
# The 40.56 40.72 False
# comprehension 40.72 41.2 False
# segment 41.2 41.74 False
# comes 41.74 42.02 False
# right 42.02 42.26 False
# here 42.26 42.68 True
# . 42.26 42.68 True
# First 43.04 43.32 True
# , 43.04 43.32 True
# we 43.4 43.46 False
# open 43.46 43.86 False
# up 43.86 44.18 False
# a 44.18 44.28 False
# list 44.28 44.6 False
# just 44.6 44.88 False
# as 44.88 45.06 False
# we 45.06 45.14 False
# normally 45.14 45.4 False
# would 45.4 45.84 True
# . 45.4 45.84 True
# Next 46.24 46.54 True
# , 46.24 46.54 True
# we 46.58 46.74 True
# 're 46.58 46.74 True
# going 46.74 46.86 False
# to 46.86 46.96 False
# grab 46.96 47.26 False
# the 47.26 47.44 False
# first 47.44 47.84 False
# index 47.84 48.26 False
# for 48.26 48.6 False
# each 48.6 48.88 False
# thing 48.88 49.1 False
# that 49.1 49.24 False
# we 49.24 49.26 True
# 're 49.24 49.26 True
# going 49.26 49.38 False
# to 49.38 49.48 False
# iterate 49.48 49.7 False
# over 49.7 50.34 True
# , 49.7 50.34 True
# in 50.38 50.52 False
# this 50.52 50.68 False
# case 50.68 50.94 False
# N. 50.94 51.4 False
# And 51.72 51.82 False
# then 51.82 51.92 False
# the 51.92 52.02 False
# second 52.02 52.26 False
# component 52.26 52.62 False
# of 52.62 52.86 False
# list 52.86 53.06 False
# comprehension 53.06 53.44 False
# is 53.44 53.9 False
# a 53.9 54.04 False
# standard 54.04 54.3 False
# for 54.3 54.58 False
# loop 54.58 54.84 True
# . 54.58 54.84 True
# And 55.02 55.14 False
# if 55.14 55.3 False
# you 55.3 55.36 False
# print 55.36 55.52 False
# this 55.52 55.7 False
# off 55.7 55.94 True
# , 55.7 55.94 True
# we 56.12 56.22 False
# get 56.22 56.42 False
# the 56.42 56.56 False
# exact 56.56 56.92 False
# result 56.92 57.2 False
# that 57.2 57.38 False
# we 57.38 57.44 False
# would 57.44 57.56 False
# expect 57.56 58.0 True
# . 57.56 58.0 True
# The 58.24 58.24 False
# first 58.24 58.46 False
# letter 58.46 58.74 False
# of 58.74 59.12 False
# each 59.12 59.42 False
# name 59.42 59.76 True
# . 59.42 59.76 True

# %%
for ent in doc.ents:
    if ent.label_ == "PERSON":
        print(ent, ent.label_, ent._.start_time, ent._.end_time)
# Out:
# Tom PERSON 8.4 8.66
# Bob PERSON 9.24 9.54
# Tom PERSON 24.64 24.94
# Bob PERSON 24.94 25.2
# N. PERSON 50.94 51.82

# %%
for sent in doc.sents:
    print(sent.text, sent._.start_time, sent._.end_time)
# Out:
# One of the most useful things you can learn as an intermediate Python student is comprehension. 0.0 4.04
# List comprehension looks something like this. 4.72 6.68
# Imagine we had a list of names, Tom, Cat, and Bob. 7.0 9.54
# And I imagine we wanted to grab just the first letter of each of these names. 9.72 12.86
# We can do so with list comprehension. 13.18 14.84
# Believe it or not, this code is identical to the result that you would get from this code here. 15.46 20.22
# Let's break down list comprehension step by step. 20.5 22.8
# First, we have our list of names, Tom, Bob, and Cat. 23.1 25.58
# Now we're going to use list comprehension. 25.92 27.54
# In this case, we're creating an object called L, and it's going to grab the first letter of each of these names. 27.54 33.48
# First, we create our object L. 33.82 35.46
# This is where we're going to start creating a list that's going to be populated by our comprehension. 35.76 39.94
# The comprehension segment comes right here. 40.56 42.68
# First, we open up a list just as we normally would. 43.04 45.84
# Next, we're going to grab the first index for each thing that we're going to iterate over, in this case N. 46.24 51.4
# And then the second component of list comprehension is a standard for loop. 51.72 54.84
# And if you print this off, we get the exact result that we would expect. 55.02 58.0
# The first letter of each name. 58.24 59.76
